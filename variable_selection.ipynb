# %%
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import sys
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
from sklearn import preprocessing
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import statsmodels.api as sm
import matplotlib.pyplot as plt
from pandas_datareader import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
kospi=pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/swcon_capstone/kospi_cluster_dbc_결과.csv',encoding='cp949',index_col=0)

# %%
kospi=kospi.T
kospi
# Out:
#             Cluster0  Cluster1  Cluster2  ...    외인순매수        시가총액   원달러환율
# 2016-01-04  0.283759  0.645588  0.662787  ...  -1572.0  12153840.0  1187.7
# 2016-01-05  0.287997  0.647707  0.668506  ...  -1897.0  12226220.0  1188.0
# 2016-01-06  0.287870  0.643110  0.674694  ...   1631.0  12192970.0  1197.9
# 2016-01-07  0.277496  0.632905  0.663594  ...  -2693.0  12055460.0  1200.6
# 2016-01-08  0.275042  0.633452  0.668734  ...  -1492.0  12137390.0  1198.1
# ...              ...       ...       ...  ...      ...         ...     ...
# 2020-09-23  0.378983  0.297599  0.228402  ...   -559.0  15879240.0  1164.4
# 2020-09-24  0.354170  0.276285  0.210701  ...  -1915.0  15473210.0  1172.7
# 2020-09-25  0.356235  0.280513  0.213173  ...   -899.0  15519150.0  1172.3
# 2020-09-28  0.374154  0.290853  0.221021  ...   -580.0  15711280.0  1173.6
# 2020-09-29  0.385736  0.299038  0.226006  ...   -712.0  15844650.0  1169.5
#
# [1159 rows x 8 columns]

# %%
kospi.corr()
# Out:
#           Cluster0  Cluster1  Cluster2  ...     외인순매수      시가총액     원달러환율
# Cluster0  1.000000  0.184712 -0.323057  ...  0.075186  0.774120 -0.657867
# Cluster1  0.184712  1.000000  0.808809  ...  0.264395  0.165880 -0.643878
# Cluster2 -0.323057  0.808809  1.000000  ...  0.226646 -0.265657 -0.245838
# Cluster3  0.218691 -0.728008 -0.654770  ... -0.079617  0.267464  0.321460
#   거래대금    0.004939 -0.560833 -0.411136  ... -0.184111  0.301209  0.203199
#   외인순매수   0.075186  0.264395  0.226646  ...  1.000000  0.066736 -0.177365
#   시가총액    0.774120  0.165880 -0.265657  ...  0.066736  1.000000 -0.614651
# 원달러환율    -0.657867 -0.643878 -0.245838  ... -0.177365 -0.614651  1.000000
#
# [8 rows x 8 columns]
