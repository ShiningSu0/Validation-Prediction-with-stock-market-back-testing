# %%
import ast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import sys
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
from sklearn import preprocessing
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import statsmodels.api as sm
import matplotlib.pyplot as plt
from pandas_datareader import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/gdrive

# %%
kospi=pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/swcon_capstone/kospi_price_data.csv',encoding='cp949',index_col=0)

# %%
def min_max_normalize(lst):
    normalized = []
    
    for value in lst:
      if (max(lst)-min(lst))==0:
        normalized.append(0)
      else:
        normalized_num = (value - min(lst)) / (max(lst) - min(lst))
        normalized.append(normalized_num)
    
    return normalized

# %%
kospi
# Out:
#           2016-01-04    2016-01-05  ...  2020-09-28  2020-09-29
# 한화생명     7220.000000   7260.000000  ...      1480.0      1525.0
# 미래에셋대우   9000.000000   8960.000000  ...      8430.0      8480.0
# 기업은행    12050.000000  12400.000000  ...      7910.0      8010.0
# SK하이닉스  30150.000000  30600.000000  ...     82500.0     84000.0
# 한국전력공사  50000.000000  50700.000000  ...     20200.0     20400.0
# ...              ...           ...  ...         ...         ...
# 미래산업      423.645996    428.161987  ...      3205.0      3300.0
# 미원홀딩스   29775.500000  30164.699220  ...     53500.0     55500.0
# 시디즈     16000.000000  16250.000000  ...     59800.0     60300.0
# 조선선재    64300.000000  64300.000000  ...     97000.0     97900.0
# 엘브이엠씨    9149.530273   9327.099609  ...      3560.0      3530.0
#
# [722 rows x 1159 columns]

# %%
name=list(kospi.index)
name
# Out:
# ['한화생명',
#  '미래에셋대우',
#  '기업은행',
#  'SK하이닉스',
#  '한국전력공사',
#  '삼성중공업',
#  'LG유플러스',
#  '신한지주',
#  '기아자동차',
#  'KB금융',
#  '대우건설',
#  '맥쿼리인프라',
#  'LG디스플레이',
#  'HMM',
#  'BNK금융지주',
#  '케이티',
#  'NH투자증권',
#  '하나금융지주',
#  '현대자동차',
#  '금호타이어',
#  '두산중공업',
#  '아시아나항공',
#  '한화투자증권',
#  '유안타증권',
#  '두산인프라코어',
#  'JB금융지주',
#  '삼성엔지니어링',
#  '케이티앤지',
#  'LG전자',
#  '삼성전자',
#  '미래에셋생명',
#  'LG',
#  '대한항공',
#  'DGB금융지주',
#  '한화솔루션',
#  '동양생명',
#  '쌍용자동차',
#  '메리츠증권',
#  '현대제철',
#  'SK네트웍스',
#  '포스코인터내셔널',
#  '삼성카드',
#  '동국제강',
#  '한화손해보험',
#  '현대건설',
#  '현대로템',
#  '대우조선해양',
#  '유진증권',
#  '팬오션',
#  '쌍용양회공업',
#  'KG동부제철',
#  '현대모비스',
#  '한화',
#  '한국항공우주',
#  '포스코',
#  'GS',
#  'SK이노베이션',
#  '맵스리얼티1',
#  '한국가스공사',
#  '삼성증권',
#  '대신증권',
#  '대한전선',
#  '한진중공업',
#  'GS건설',
#  '한국패러랠',
#  'LS네트웍스',
#  'LG화학',
#  '삼성전기',
#  '하이트진로',
#  '삼성SDI',
#  '한국조선해양',
#  '한국ANKOR유전',
#  '우리종금',
#  '흥국화재',
#  '교보증권',
#  '롯데손해보험',
#  '한국금융지주',
#  'KTB투자증권',
#  'HDC',
#  'S-Oil',
#  '아주캐피탈',
#  '한화에어로스페이스',
# ...

# %%
kospi_preprocessed=kospi.loc[:,[]]
kospi_preprocessed
# Out:
# Empty DataFrame
# Columns: []
# Index: [한화생명, 미래에셋대우, 기업은행, SK하이닉스, 한국전력공사, 삼성중공업, LG유플러스, 신한지주, 기아자동차, KB금융, 대우건설, 맥쿼리인프라, LG디스플레이, HMM, BNK금융지주, 케이티, NH투자증권, 하나금융지주, 현대자동차, 금호타이어, 두산중공업, 아시아나항공, 한화투자증권, 유안타증권, 두산인프라코어, JB금융지주, 삼성엔지니어링, 케이티앤지, LG전자, 삼성전자, 미래에셋생명, LG, 대한항공, DGB금융지주, 한화솔루션, 동양생명, 쌍용자동차, 메리츠증권, 현대제철, SK네트웍스, 포스코인터내셔널, 삼성카드, 동국제강, 한화손해보험, 현대건설, 현대로템, 대우조선해양, 유진증권, 팬오션, 쌍용양회공업, KG동부제철, 현대모비스, 한화, 한국항공우주, 포스코, GS, SK이노베이션, 맵스리얼티1, 한국가스공사, 삼성증권, 대신증권, 대한전선, 한진중공업, GS건설, 한국패러랠, LS네트웍스, LG화학, 삼성전기, 하이트진로, 삼성SDI, 한국조선해양, 한국ANKOR유전, 우리종금, 흥국화재, 교보증권, 롯데손해보험, 한국금융지주, KTB투자증권, HDC, S-Oil, 아주캐피탈, 한화에어로스페이스, 한국토지신탁, SK증권, 대성산업, DB하이텍, 세아베스틸, 대림산업, DB금융투자, GS글로벌, 현대엘리베이터, 호텔신라, 현대미포조선, 에이프로젠제약, 한라, LG상사, LG헬로비전, 제주항공, SKC, 금호산업, ...]
#
# [722 rows x 0 columns]

# %%
ary=[]
for i in range(722):
  lst=list(kospi.iloc[i])
  lst=min_max_normalize(lst)
  ary.append(lst)

# %%
len(ary)
# Out:
# 722

# %%
ary=pd.DataFrame(ary)

# %%
ary
# Out:
#          0         1         2     ...      1156      1157      1158
# 0    0.879083  0.884642  0.886032  ...  0.077832  0.081306  0.087561
# 1    0.683744  0.678684  0.653384  ...  0.601518  0.611638  0.617963
# 2    0.545455  0.576346  0.563107  ...  0.174757  0.180053  0.188879
# 3    0.055521  0.061199  0.063091  ...  0.721136  0.716088  0.735016
# 4    0.721925  0.736898  0.739037  ...  0.073797  0.084492  0.088770
# ..        ...       ...       ...  ...       ...       ...       ...
# 717  0.090443  0.091607  0.089744  ...  0.766572  0.807841  0.832345
# 718  0.006094  0.010157  0.009141  ...  0.258938  0.253719  0.274594
# 719  0.016021  0.019359  0.014686  ...  0.599466  0.600801  0.607477
# 720  0.062361  0.062361  0.067929  ...  0.415367  0.426503  0.436526
# 721  0.785503  0.804371  0.777559  ...  0.180422  0.191579  0.188392
#
# [722 rows x 1159 columns]

# %%
ary.to_csv('/content/gdrive/My Drive/Colab Notebooks/swcon_capstone/kospi_preprocessed.csv')
